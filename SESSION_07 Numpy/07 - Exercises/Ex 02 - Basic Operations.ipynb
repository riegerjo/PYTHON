# %% [markdown]
# # Numpy
#
# ## Basic Operations

# %% [markdown]
# 1. Import the numpy library and check its version.

# %% [markdown]
# 2. Create two 2-D arrays (each one 2x3) and assign them to the variable **ar1** and **ar2** rispectively.

# %%
# ar1

# %%
# ar2

# %% [markdown]
# ## Arithmetic

# %% [markdown]
# Arithmetic operators on arrays apply *elementwise*. A new array is created and filled with the result

# %% [markdown]
# 3. **Multiply** the ar1 and ar2

# %% [markdown]
# 3. **Subtract** the ar1 and ar2

# %% [markdown]
# 4. **Sum** the ar1 and ar2 and assign the result (new array) into a new variable. **Divide** the ar1 with the new array.

# %% [markdown]
# 5. Calculate the esponential ^2 to every element of ar1

# %% [markdown]
# #### Comparison
#
# 6. Check if your array has a value greater than 10

# %% [markdown]
# ## Sum, Min, Max, Mean and Std of an Array
#
# 7. Create a 1-D array using the **linespace** method and assign it to the **'x'** variable. The array should start at 1, stop at 15 and carring 30 elements inside.

# %% [markdown]
# 8. Sum all the elements of the x array

# %% [markdown]
# 9. Find the minimum value of x

# %% [markdown]
# 10. Find the maximum value of x

# %% [markdown]
# 11. Find the mean of x

# %% [markdown]
# 12. Find the standard deviation of x

# %% [markdown]
# ### Sum, Min, Max, Mean and Std on array axis
#
# Here we work on specific axis

# %%
from IPython.display import Image
Image(filename='../../Images/np2darray.PNG')

# %% [markdown]
# 13. Risize (in-place) the x array (5x6) and print it.

# %% [markdown]
# 14. Sum x on **rows**

# %% [markdown]
# 15. Sum x **on columns**

# %% [markdown]
# ## Matrix product

# %% [markdown]
# 16. Given the following arrays (A and B) calculate the **'dot product'** with the two methods you know.

# %%
A = np.array( [[1,1,3], [0,1,2]] )
B = np.array( [[2,0,1], [3,4,1]] )

# %% [markdown]
# ## Congratulation! You have completed the exercises!
