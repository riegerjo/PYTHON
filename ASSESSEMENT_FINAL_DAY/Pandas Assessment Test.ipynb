# %% [markdown]
# # Pandas Test

# %% [markdown]
# Import pandas and numpy

# %%
# imports
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Use the data below and write a Pandas program to create a DataFrame, than add a new column name "A" that will be the sum of "Y" and "Z".

# %%
data = {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}

# %%
# create the df
ef = pd.DataFrame(data)

ef
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
# create a new column
ef['V'] = 1
ef
# Out:
#     X   Y   Z  V
# 0  78  84  86  1
# 1  85  94  97  1
# 2  96  89  96  1
# 3  80  83  72  1
# 4  86  86  83  1

# %% [markdown]
# 2. Use the data below, write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', np.NaN, 'Kevin', 'Jonas'],
            'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
            'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
            'qualify': ['yes', np.nan, 'yes', 'no', 'no', 'yes', 'yes', np.NaN, 'no', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# create the df
df = pd.DataFrame(exam_data)
df.index = labels

# %% [markdown]
# 3. Get general info from your DataFrame of point 2.

# %%
df.info
# Out:
# <bound method DataFrame.info of         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3     NaN
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h        NaN    NaN         1     NaN
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes>

# %% [markdown]
# 4. Describe your DataFrame

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3     NaN
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h        NaN    NaN         1     NaN
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes>

# %% [markdown]
# 5. Use the DataFrame you created before and find all the columns that carry any NaN value. Than count how many NaN values there are in every column.

# %%
# find NaN values for every column

df.isna()
# Out:
#     name  score  attempts  qualify
# a  False  False     False    False
# b  False  False     False     True
# c  False  False     False    False
# d  False   True     False    False
# e  False  False     False    False
# f  False  False     False    False
# g  False  False     False    False
# h   True   True     False     True
# i  False  False     False    False
# j  False  False     False    False

# %%
# count the NaN values


df.isna().sum()   # or s.isnull().sum() for older pandas versions
# Out:
# name        1
# score       2
# attempts    0
# qualify     2
# dtype: int64

# %% [markdown]
# 6. Use the same DataFrame and substitute the NaN values in the "score" column with the mean of column itself. **Note:** Do not use inplace method.

# %%
# will replace  Nan value in dataframe with value -99999  
df['score'] = df[['score']].replace(to_replace = np.nan, value = df.mean(axis = 0)['score'])

# %%
df
# Out:
#         name    score  attempts qualify
# a  Anastasia  12.5000         1     yes
# b       Dima   9.0000         3     NaN
# c  Katherine  16.5000         2     yes
# d      James  13.5625         3      no
# e      Emily   9.0000         2      no
# f    Michael  20.0000         3     yes
# g    Matthew  14.5000         1     yes
# h        NaN  13.5625         1     NaN
# i      Kevin   8.0000         2      no
# j      Jonas  19.0000         1     yes

# %% [markdown]
# 7. Use the same DataFrame, remove all the line that has at least one NaN value. **Note:** Do not use inplace method.

# %%
# Drop nan
df.dropna()
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# 8. Drop the row/s that has less than two data points.

# %%
 df.dropna(thresh=2)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3     NaN
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# 9. Use the same DataFrame an drop all columns tha has any NaN value

# %%
df.dropna()
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# 10. Use the same DataFrame and select all the rows where the "score" is NaN.

# %% [markdown]
# 11. Open the file "gdp_minder.csv" in the folder /Data and create a new DataFrame, name it "gdp_df"

# %%
# read the csv file
gdp_df =
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# 12. Get general info about the "gdp_df"

# %%
# df info

# %% [markdown]
# 13. Slice the gdp_df and select the data where "continent == Europe" and "year == 2007". Save the data into a new DataFrame named "eu_df"

# %%
# slice the df
eu_df =

# %% [markdown]
# 14. Work on the "eu_df" and find out the country whom has the minimum life expectation

# %% [markdown]
# 15. Use the "eu_df" and select the country whom has the highest population.

# %% [markdown]
# 16. Use the "eu_df" and select country with the highest 'gdpPercap'

# %% [markdown]
# #### From now we will use the "gdp_df"

# %% [markdown]
# 17. Use the gdp_df and find all the unique values into the "continent" column.

# %% [markdown]
# 18. Work on the "gdp_df". Select all the information about the Asian countries in the year 2002.

# %% [markdown]
# 19. Select what Asian country has the maximun gdpPercap in the year 2007.

# %%
# Out:
#         country  year        pop continent  lifeExp   gdpPercap
# 1366  Singapore  2002  4197776.0      Asia    78.77  36023.1054

# %% [markdown]
# 20. Use the "gdp_df" and find out the total population for each continent for each year. **Hint:** Use the groupby method [link](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)

# %%
# Out:
#                          pop     lifeExp      gdpPercap
# continent year
# Africa    1952  2.376405e+08  2035.04600   65133.768223
#           1957  2.648377e+08  2145.85000   72032.275237
#           1962  2.965169e+08  2252.61100   83100.098892
#           1967  3.352895e+08  2357.39600  106618.917645
#           1972  3.798795e+08  2467.44900  121660.015058
#           1977  4.330610e+08  2578.18200  134468.802440
#           1982  4.993486e+08  2682.82900  129042.833907
#           1987  5.748341e+08  2773.92900  118698.787546
#           1992  6.590815e+08  2788.73800  118654.137329
#           1997  7.438330e+08  2787.11000  123695.496865
#           2002  8.337239e+08  2772.91200  135168.028262
#           2007  9.295397e+08  2849.91400  160629.695446
# Americas  1952  3.451524e+08  1331.99600  101976.563805
#           1957  3.869539e+08  1399.00700  115401.093329
#           1962  4.332703e+08  1459.96900  122538.546760
# ...

# %% [markdown]
# # The End!
