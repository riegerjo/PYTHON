# %% [markdown]
# import numpy as np

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
area_house = np.random.rand(500)*10
prices = 7* area_house +3

# %%
plt.scatter(area_house, prices)

# %% [markdown]
# # Section_1

# %% [markdown]
# In vector X_sq you have the feature "House Squared Meters", in the y the "Price" of the houses

# %% [markdown]
# ## Check the shape of X_sq and y

# %%
print(X_sq.shape)
# Out:
# (100, 1)

# %%
print(y.shape)
# Out:
# (100, 1)

# %% [markdown]
# ## 1.1 Plot the X and Y in a plot

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(16, 9))
ax = plt.axes()
ax.scatter(X_sq, y)
ax.grid()
ax.set(xlabel='X', title='X and y');

# %% [markdown]
# First, check the type of variable called <b>X_sq</b>. Use command <b>type(arg)</b> to know what is <b>X_sq</b>.

# %%
type(X_sq)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Use a FOR loop to calculate the price for each house given parameters

# %% [markdown]
# Suppose you have the model (=have theta0 and theta1) and you want to calculate the price of houses with Squared. This is equivalent to have the Linear model (the rect fitting the data)<br><br> Meters values stores in list <b>new_sq</b><br>
# <br>
# Create a "Price" list and add the results to "Price". <br>Remember: Theta0 = 14, Theta1 = 2.346.
# <br>
# The equation is Price = Theta0 + Theta1 * X_sq

# %%
new_sq = np.random.randint(3, 500, 100).tolist()
theta0 = 30
theta1 = 3
# Use X_sq (the list of meters squared)

Price = list()
# USE X_sq_list: it is the list of the values in X_sq

for x in new_sq:
    new_price = theta0 + theta1 * x
    Price.append(new_price)
print(Price)
# Out:
# [714, 867, 894, 327, 888, 1137, 1380, 1479, 1395, 987, 948, 477, 48, 141, 612, 183, 87, 552, 696, 510, 1467, 174, 1155, 54, 333, 1176, 735, 147, 876, 1083, 1527, 942, 579, 321, 333, 600, 1479, 384, 609, 795, 1443, 1284, 1449, 519, 804, 1005, 420, 90, 879, 1506, 705, 198, 210, 1005, 1116, 558, 876, 378, 900, 1329, 1062, 489, 1386, 417, 501, 1506, 1194, 1458, 855, 348, 1287, 1215, 933, 774, 564, 153, 1467, 546, 777, 114, 1101, 954, 1263, 1260, 75, 984, 1209, 975, 144, 555, 96, 999, 828, 1518, 1236, 462, 1416, 1149, 1449, 465]

# %% [markdown]
# ## Plot the new values found (Price)

# %%
fig = plt.figure(figsize=(16, 9))
ax = plt.axes()

ax.scatter(X_sq_list, y, color='blue', label='Dataset data')
ax.scatter(new_sq, Price, color='red', label='Predicted Data')
ax.legend()
ax.grid()
ax.set(title='Scatter plot', xlabel='$Squared Meters$', ylabel='$Prices$');

# %% [markdown]
# # SECTION2: find the parameters theta0 and theta1 from data

# %% [markdown]
# # Linear regression using the Normal Equation

# %%
X_sq = np.random.uniform(2, 500, size=(100, 1))
y = 200 + 3 * X_sq + np.random.randn(100, 1)*50
X_sq_list = X_sq.ravel().tolist()

# %%
X_b = np.c_[np.ones((100, 1)), X_sq]  # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
# Out:
# array([[205.18324769],
#        [  2.95582003]])

# %% [markdown]
# ## Plot the Regression Line with data

# %%
X_new = np.array([[0], [500]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 205.18324769],
#        [1683.09326165]])

# %%
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
plt.plot(X_sq, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
# plt.axis([0, 2, 0, 15])
plt.grid()
plt.show()

# %% [markdown]
# # Linear regression using batch gradient descent

# %%
def  cal_cost(theta,X,y):
    '''
    
    Calculates the cost for given X and Y. The following shows and example of a single dimensional X
    theta = Vector of thetas 
    X     = Row of X's np.zeros((2,j))
    y     = Actual y's np.zeros((2,1))
    
    where:
        j is the no of features
    '''
    
    m = len(y)
    
    predictions = X.dot(theta)
    cost = (1/2*m) * np.sum(np.square(predictions-y))
    return cost

def gradient_descent(X,y,theta,learning_rate=0.01,iterations=100):
    '''
    X    = Matrix of X with added bias units
    y    = Vector of Y
    theta=Vector of thetas np.random.randn(j,1)
    learning_rate 
    iterations = no of iterations
    
    Returns the final theta vector and array of cost history over no of iterations
    '''
    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    for it in range(iterations):
        
        prediction = np.dot(X,theta)
        errors_vector = prediction - y
        
        theta = theta - ((2/m)*(X.T.dot(errors_vector)))* learning_rate
        theta_history[it,:] = theta.T
        cost_history[it]  = cal_cost(theta,X,y)
        
    return theta, cost_history, theta_history

# %%
lr =0.001
n_iter = 50000

np.random.seed(0)

X = np.random.uniform(2, 50, size=(1000, 1))
y = 200 + 3 * X + np.random.randn(1000,1) * 20

theta = np.random.randn(2,1)

X_b = np.c_[np.ones((len(X),1)),X]

theta,cost_history,theta_history = gradient_descent(X_b,y,theta,lr,n_iter)

# %%
plt.scatter(X, y)

# %%
theta
# Out:
# array([[201.62420967],
#        [  2.95956764]])

# %% [markdown]
# # Get parameters with Sklearn Linear Regression Class

# %%
X = np.random.uniform(2, 500, size=(1000, 1))
y = 200 + 3 * X + np.random.randn(1000,1) * 40

from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([201.37093859]), array([[2.98946727]]))

# %%
X_new = np.array([[0], [500]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = lin_reg.predict(X_new)

plt.plot(X, y, "b.")
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")

plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
# plt.axis([0, 2, 0, 15])
# save_fig("linear_model_predictions")
plt.grid()
plt.show()

# %% [markdown]
# # Section 3

# %%
# SETUP: DONT TOUCH IT

import numpy as np
import numpy.random as rnd

np.random.seed(42)
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %% [markdown]
# # Polynomial regression

# %%
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-3, 3, 0, 10])
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)
X[0]
# Out:
# array([-0.75275929])

# %%
X_poly[0]
# Out:
# array([-0.75275929,  0.56664654])

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([1.78134581]), array([[0.93366893, 0.56456263]]))

# %%
X_new=np.linspace(-3, 3, 100).reshape(100, 1)
X_new_poly = poly_features.transform(X_new)
y_new = lin_reg.predict(X_new_poly)
plt.plot(X, y, "b.")
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.grid()

# %% [markdown]
# # Section 4: Overfitting

# %%
# SETUP: DONT TOUCH IT

import numpy as np
import numpy.random as rnd

np.random.seed(42)
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %% [markdown]
# Your task is fitting the data with a Polynomial Regression, building 5 models with different polynomial expansion.<br>
# The degrees to use are in array "degrees". Use a for loop to fit the data with different degrees. Use PolynomialFeatures(degree=..., include_bias=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
degrees = np.arange(2,30,5)

# %%
plt.figure(figsize=(16,9))
for deg in degrees:
    # Calculate ploy_features
    poly_features = PolynomialFeatures(degree=deg, include_bias=False)
    X_poly = poly_features.fit_transform(X)
    # Fit the data with Linear Regression
    lin_reg = LinearRegression()
    lin_reg.fit(X_poly, y)
    
    # Plot function: DONT TOUCH IT PLEASE
    X_new=np.linspace(-3, 3, 100).reshape(100, 1)
    X_new_poly = poly_features.transform(X_new)
    y_new = lin_reg.predict(X_new_poly)
    plt.plot(X, y, "b.")
    plt.plot(X_new, y_new, linewidth=2, label=deg)
    plt.xlabel("$x_1$", fontsize=18)
    plt.ylabel("$y$", rotation=0, fontsize=18)
    plt.axis([-3, 3, 0, 10])
    plt.legend()
plt.grid()

# %% [markdown]
# # Section 5: Regularization Example

# %% [markdown]
# ## Data Generation (Don't touch it please)

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

def generate_data():
    np.random.seed(42)
    m = 25
    X = 3 * np.random.rand(m, 1)
    y = 10 + 2 * X**2 + np.random.randn(m, 1) * 3
    X_new = np.linspace(0, 3, 100).reshape(100, 1)
    return X, y, X_new, m

X, y, X_new, m = generate_data()

import matplotlib.pyplot as plt
plt.plot(X, y, "b.", linewidth=3)
plt.xlabel("$x_1$", fontsize=18)
# Out:
# Text(0.5, 0, '$x_1$')

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

np.random.seed(42)
m = 20
X = 3 * np.random.rand(m, 1)
y = 1 + 0.5 * X + np.random.randn(m, 1) / 1.5
X_new = np.linspace(0, 3, 100).reshape(100, 1)

def plot_model(model_class, degree, alphas, **model_kargs):
    for alpha, style in zip(alphas, ("b-", "g--", "r:")):
        model = model_class(alpha, **model_kargs) if alpha > 0 else LinearRegression()
        
        if degree is not None:
            model = Pipeline([
                    ("poly_features", PolynomialFeatures(degree=10, include_bias=False)),
                    ("std_scaler", StandardScaler()),
                    ("regul_reg", model),
                ])
        model.fit(X, y)
        y_new_regul = model.predict(X_new)
        
        lw = 2 if alpha > 0 else 1
        plt.plot(X_new, y_new_regul, style, linewidth=lw, label=r"$\alpha = {}$".format(alpha))
    plt.plot(X, y, "b.", linewidth=3)
    plt.legend(loc="upper left", fontsize=15)
    plt.xlabel("$x_1$", fontsize=18)
    plt.axis([0, 3, 0, 4])
    return model

plt.figure(figsize=(8,4))

plt.subplot(121)
plot_model(Ridge, degree=None, alphas=(0, 10, 100), random_state=42)
plt.ylabel("$y$", rotation=0, fontsize=18)

plt.subplot(122)
plot_model(Ridge, degree=30, alphas=(0, 10**-5, 1), random_state=42)

plt.show()

# %%
np.random.seed(42)
m = 20
X = 3 * np.random.rand(m, 1)
y = 1 + 0.5 * X + np.random.randn(m, 1) / 1.5
X_new = np.linspace(0, 3, 100).reshape(100, 1)

model = Pipeline([
        ("poly_features", PolynomialFeatures(degree=10, include_bias=False)),
        ("std_scaler", StandardScaler()),
        ("regul_reg", Ridge()),
    ])

model.fit(X, y)
model[2].coef_
# Out:
# array([[ 0.19242496, -0.05219979, -0.05187216, -0.02809326, -0.00486859,
#          0.01898063,  0.04493381,  0.07311   ,  0.10293252,  0.13360102]])

# %% [markdown]
# ## Lasso Regularization

# %%
from sklearn.linear_model import Lasso

plt.figure(figsize=(8,4))
plt.subplot(121)
plot_model(Lasso, degree=None, alphas=(0, 0.1, 1), random_state=42)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.subplot(122)
plot_model(Lasso, degree=10, alphas=(0, 10**-7, 1), tol=1, random_state=42)

# save_fig("lasso_regression_plot")
plt.show()

# %%
np.random.seed(42)
m = 20
X = 3 * np.random.rand(m, 1)
y = 1 + 0.5 * X + np.random.randn(m, 1) / 1.5
X_new = np.linspace(0, 3, 100).reshape(100, 1)

model = Pipeline([
        ("poly_features", PolynomialFeatures(degree=10, include_bias=False)),
        ("std_scaler", StandardScaler()),
        ("regul_reg", Ridge()),
    ])

model.fit(X, y)
model[2].coef_
# Out:
# array([[ 0.19242496, -0.05219979, -0.05187216, -0.02809326, -0.00486859,
#          0.01898063,  0.04493381,  0.07311   ,  0.10293252,  0.13360102]])
