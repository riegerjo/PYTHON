# %% [markdown]
# # R2 Squared, Mean Absolute Error, Mean Squared Error

# %% [markdown]
# ## Section 1

# %%
# SETUP: DONT TOUCH IT

import numpy as np
import numpy.random as rnd

np.random.seed(42)
m = 1000
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**6 + X**4 + X**2 + 2 + np.random.randn(m, 1)

# %% [markdown]
# Plot the data

# %%
import matplotlib.pyplot as plt

plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-3, 3, 0, 10])
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

my_pipeline = Pipeline([('polinomial', PolynomialFeatures(degree=6)),
                        ('Lin_reg', LinearRegression())])

my_pipeline.fit(X, y)
# Out:
# Pipeline(memory=None,
#          steps=[('polinomial',
#                  PolynomialFeatures(degree=6, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('Lin_reg',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
print('Coeff: {}'.format(my_pipeline[1].coef_))
# Out:
# Coeff: [[ 0.          0.04908701  0.85099108 -0.02687134  1.03038704  0.00201263
#    0.49830597]]

# %%
X_new=np.linspace(-3, 3, 100).reshape(100, 1)

y_new = my_pipeline.predict(X_new)

plt.plot(X, y, "b.")
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.grid()

# %% [markdown]
# ## Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %% [markdown]
# ## Calculate the
# - R Squares given X and y
# - Root Mean Squared Error given X and y
# - Mean Absolute Error given X and y

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Calculate R2 Score

# %%
r2_score(y, my_pipeline.predict(X))
# Out:
# 0.999918430571303

# %% [markdown]
# Calculate Mean Absolute Error

# %%
mean_absolute_error(y, my_pipeline.predict(X))
# Out:
# 0.7785100924225501

# %% [markdown]
# Calculate Mean Squared Error (MSE) and Root Mean Absolute Error (RMSE)

# %%
mean_squared_error(y, my_pipeline.predict(X))
# Out:
# 0.9600681068794509

# %%
np.sqrt(mean_squared_error(y, my_pipeline.predict(X)))
# Out:
# 0.9798306521432419

# %% [markdown]
# Now, suppose you don't know the degree of the equation, but you have only data. With a For Loop, calculate the R2 Squares, MSE, RMSE, MAE for each degree of Polynomial from 1 to 10.

# %%
list_of_r2, list_mae, list_mse, list_rmse = [], [], [] , []
for deg in np.arange(0, 10):
    my_pipeline = Pipeline([('polinomial', PolynomialFeatures(degree=deg)),
                            ('Lin_reg', LinearRegression())])

    my_pipeline.fit(X, y)
    list_of_r2.append(r2_score(y, my_pipeline.predict(X)))
    list_mae.append(mean_absolute_error(y, my_pipeline.predict(X)))
    list_mse.append(mean_squared_error(y, my_pipeline.predict(X)))
    list_rmse.append(np.sqrt(mean_squared_error(y, my_pipeline.predict(X))))

# %% [markdown]
# Plot 4 plots with subplot: one for each metric

# %%
fig = plt.figure(figsize=(16, 9))
titles = ['r2', 'mae', 'mse', 'rmse']
for ind, obj in enumerate([list_of_r2, list_mae, list_mse, list_rmse]):
    fig.add_subplot(2, 2, ind+1)
    plt.plot(obj)
    plt.title(titles[ind])
    plt.grid()
