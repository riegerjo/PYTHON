# %% [markdown]
# # Titanic - with Decision Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Titanica Dataset

# %%
df_titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# # Some Data Exploration

# %% [markdown]
# ### How many Survived and Deads?

# %%
sns.countplot(data=df_titanic, x='Survived')
plt.grid()

# %% [markdown]
# ### How many male and female?

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_axes()
sns.countplot(data=df_titanic, x='Sex', ax=ax)
plt.grid()

# %% [markdown]
# ### Plot the distribution of the Fare based on classes

# %%
fig = plt.figure(figsize=(16, 5))
for class_ in df_titanic['Pclass'].unique():
    sns.kdeplot(df_titanic[df_titanic['Pclass']==class_]['Fare'], 
                label=class_, shade=True)
plt.xlim(0,400)
plt.grid()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_titanic.drop('Survived', axis=1), 
                                                    df_titanic['Survived'], 
                                                    stratify=df_titanic['Survived'])

# %%
train_set.head()
# Out:
#      Survived  Pclass  SibSp  Parch      Fare
# 680         0       3      0      0    8.1375
# 91          0       3      0      0    7.8542
# 445         1       1      0      2   81.8583
# 118         0       1      0      1  247.5208
# 667         0       3      0      0    7.7750

# %% [markdown]
# # Check the ratio of Survived in train and test sets

# %% [markdown]
# ### Is it true that the % of survived in Train is similar to the % of Survived in the Test?

# %%
# Check the % of Survived in y_train and y_test
ratio_train = 100 * y_train.sum() / len(y_train)
print(ratio_train)
# Out:
# 38.32335329341317

# %%
ratio_test = 100 * y_test.sum() / len(y_test)
print(ratio_test)
# Out:
# 38.56502242152467

# %% [markdown]
# ## Plot the number of Survived and Dead people in y_train and y_test

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Check the distributions of the train and test features in train and test sets

# %%
X_train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   668.000000  668.000000  544.000000  668.000000  668.000000  668.000000
# mean    446.306886    2.315868   29.828750    0.559880    0.411677   32.003667
# std     261.617893    0.839747   14.839298    1.193815    0.851658   48.241697
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     218.750000    2.000000   21.000000    0.000000    0.000000    7.895800
# 50%     448.500000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     677.250000    3.000000   39.000000    1.000000    1.000000   31.275000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
X_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   223.000000  223.000000  170.000000  223.000000  223.000000  223.000000
# mean    445.080717    2.286996   29.284294    0.412556    0.291480   32.804931
# std     244.702822    0.826455   13.510254    0.759459    0.643939   53.918865
# min       6.000000    1.000000    0.830000    0.000000    0.000000    0.000000
# 25%     233.500000    2.000000   20.000000    0.000000    0.000000    7.925000
# 50%     442.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     652.500000    3.000000   36.750000    1.000000    0.000000   29.412500
# max     887.000000    3.000000   70.500000    5.000000    4.000000  512.329200

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
X_train.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            124
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          507
# Embarked         2
# dtype: int64

# %%
feat_to_use = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Sex']

def feature_selector(df, feature_list):
    return df[feature_list].copy()

# %%
X_train = feature_selector(X_train, feat_to_use)

# %%
X_train.isnull().sum(axis=0)
# Out:
# Pclass    0
# SibSp     0
# Parch     0
# Fare      0
# Sex       0
# dtype: int64

# %% [markdown]
# # One hot encoding of Sex

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False)
sex_encoded = ohe.fit_transform(X_train[['Sex']])

df = pd.DataFrame(sex_encoded)
df.columns = list(ohe.categories_[0])

X_train = pd.concat([X_train.reset_index(drop=True), df], axis=1)
X_train = X_train.drop('Sex', axis=1)

# %%
X_train
# Out:
#      Pclass  SibSp  Parch     Fare  female  male
# 0         2      1      1   14.500     0.0   1.0
# 1         2      1      0   26.000     0.0   1.0
# 2         1      0      0  106.425     1.0   0.0
# 3         1      1      0  227.525     1.0   0.0
# 4         3      0      0    9.500     0.0   1.0
# ..      ...    ...    ...      ...     ...   ...
# 663       1      0      0   26.550     0.0   1.0
# 664       3      4      2   31.275     0.0   1.0
# 665       3      1      2   23.450     0.0   1.0
# 666       3      1      1   20.525     0.0   1.0
# 667       3      8      2   69.550     1.0   0.0
#
# [668 rows x 6 columns]

# %% [markdown]
# # Use a DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
model = DecisionTreeClassifier(max_depth=4)

# %%
y_train.shape
# Out:
# (668,)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# # Evaluation of the model with cross validation

# %%
from sklearn.model_selection import cross_validate
pd.DataFrame(cross_validate(model, X_train, y_train, cv=5))
# Out:
#    fit_time  score_time  test_score
# 0  0.002469    0.001084    0.851852
# 1  0.002035    0.000999    0.776119
# 2  0.002117    0.001069    0.796992
# 3  0.002191    0.001265    0.789474
# 4  0.002846    0.001738    0.827068

# %% [markdown]
# # Are we happy? Try with GridSearch for Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(model, param_grid={'max_depth': np.arange(1, 10, 2), 
                                       'min_samples_leaf': np.arange(40,50)}, cv=5)
grid.fit(X_train, y_train);

# %%
grid.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 41}

# %% [markdown]
# # Ok we found the best hyperparameters for the tree!

# %%
# !pip install graphviz

# %%
dot_data = tree.export_graphviz(grid.best_estimator_, out_file=None, 
                     class_names=X_train.columns,  
                     feature_names=X_train.columns,
                     filled=True, rounded=True)
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# # Evaluation on test set

# %%
def one_hot_encoding_test_set(test_set, one_hot_enc):
    from sklearn.preprocessing import OneHotEncoder
    ohe = OneHotEncoder(sparse=False)
    sex_encoded = ohe.fit_transform(test_set[['Sex']])

    df = pd.DataFrame(sex_encoded)
    df.columns = list(ohe.categories_[0])

    test_set = pd.concat([test_set.reset_index(drop=True), df], axis=1)
    test_set = test_set.drop('Sex', axis=1)
    return test_set

# %%
feat_to_use = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Sex']
X_test = feature_selector(X_test, feat_to_use)

# %%
X_test
# Out:
#      Pclass  SibSp  Parch     Fare  female  male
# 0         1      1      1  79.6500     1.0   0.0
# 1         2      0      0  15.0458     0.0   1.0
# 2         2      0      1  19.5000     1.0   0.0
# 3         2      0      0  13.0000     0.0   1.0
# 4         3      2      0  18.0000     1.0   0.0
# ..      ...    ...    ...      ...     ...   ...
# 218       2      0      0  10.5000     0.0   1.0
# 219       3      0      0   7.9250     0.0   1.0
# 220       3      3      1  21.0750     1.0   0.0
# 221       2      0      0  26.0000     0.0   1.0
# 222       3      0      0   7.8542     0.0   1.0
#
# [223 rows x 6 columns]

# %%
X_test = one_hot_encoding_test_set(X_test, label_bin)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       137
#            1       0.71      0.72      0.72        86
#
#     accuracy                           0.78       223
#    macro avg       0.77      0.77      0.77       223
# weighted avg       0.78      0.78      0.78       223

# %% [markdown]
# A more elaborated study is found here: PLEASE FIND THE COMPLETE EXAMPLE HERE: https://towardsdatascience.com/predicting-the-survival-of-titanic-passengers-30870ccc7e8
